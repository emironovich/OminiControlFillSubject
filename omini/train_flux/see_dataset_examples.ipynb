# %%
import os
from PIL import Image
from datasets import load_dataset

# %% [markdown]
# # Subject 200k

# %%
subject_ds = load_dataset("/export/scratch/emironov/datasets/Subjects200K_processed", 
                          split="train", 
                          cache_dir= "/export/scratch/emironov/huggingface/datasets")
# Out:
# Resolving data files:   0%|          | 0/17 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/90 [00:00<?, ?it/s]

# %% [markdown]
# ## Image

# %%
# show example image
example = subject_ds[0]
image = example["image"]
image.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Subject Image

# %%
subject = example["subject"]
subject.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# # Synset

# %%
synset_ds = load_dataset("/export/scratch/emironov/datasets/synset_processed", 
                          split="train", 
                          cache_dir= "/export/scratch/emironov/huggingface/datasets")
# Out:
# Resolving data files:   0%|          | 0/17 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# show example image
example = synset_ds[0]
image = example["image"]
image.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=208x208>

# %%
subject = example["subject"]
subject.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
# compare features
print("Subject features:", subject_ds.features)
print("Synset features:", synset_ds.features)
# Out:
# Subject features: {'image': Image(mode=None, decode=True), 'description': Value('string'), 'subject': Image(mode=None, decode=True), 'mask_bbox': List(Value('int64'))}
# Synset features: {'image': Image(mode=None, decode=True), 'description': Value('string'), 'mask_bbox': List(Value('int64')), 'subject': Image(mode=None, decode=True)}
